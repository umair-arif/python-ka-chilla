# %%
import seaborn as sns
import pandas as pd
#set style theme
sns.set_style(style='whitegrid')
#load dataset
kashti=sns.load_dataset('C:/Users/HP/Desktop/Data_vis/data.csv')
#kashti=pd.read_csv('data.csv')
kashti
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-a7cb5ef91530> in <module>
#       4 sns.set_style(style='whitegrid')
#       5 #load dataset
# ----> 6 kashti=sns.load_dataset('C:/Users/HP/Desktop/Data_vis/data.csv')
#       7 #kashti=pd.read_csv('data.csv')
#       8 kashti
#
# ~\anaconda3\lib\site-packages\seaborn\utils.py in load_dataset(name, cache, data_home, **kws)
#     484         if not os.path.exists(cache_path):
#     485             if name not in get_dataset_names():
# --> 486                 raise ValueError(f"'{name}' is not one of the example datasets.")
#     487             urlretrieve(full_path, cache_path)
#     488         full_path = cache_path
#
# ValueError: 'C:/Users/HP/Desktop/Data_vis/data.csv' is not one of the example datasets.
