# %%
import seaborn as sns
sns.set_style(style='whitegrid')
kashti=sns.load_dataset('titanic')
kashti=sns.boxplot(x="class",y="fare",data=kashti)
plt.title('Titanic')
plt.show()

# %%
import seaborn as sns
sns.set_style(style='whitegrid')
tip=sns.load_dataset('tips')
tip
sns.boxplot(x='day',y='tip',data=tip,saturation=3)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
import seaborn as sns
sns.set_style(style='whitegrid')
tip=sns.load_dataset('tips')
#using indexing 
sns.boxplot(x=tip['size'])
# Out:
# <AxesSubplot:xlabel='size'>

# %%
import seaborn as sns
sns.set_style(style='whitegrid')
tip=sns.load_dataset('tips')
#using indexing 
sns.boxplot(x="tip",y="day",data=tip,color="#32a852")
# Out:
# <AxesSubplot:xlabel='tip', ylabel='day'>

# %%
import seaborn as sns
sns.set_style(style='whitegrid')
tip=sns.load_dataset('tips')
#using indexing 
sns.boxplot(x="tip",y="day",data=tip,hue='smoker')
# Out:
# <AxesSubplot:xlabel='tip', ylabel='day'>

# %%
import seaborn as sns
sns.set_style(style='whitegrid')
tip=sns.load_dataset('tips')
#using indexing 
sns.boxplot(x="tip",y="day",data=tip,hue='smoker',palette='Set1',dodge=True)
#Dodge mean two things are side-by-side to eachother if True else they will overlap or cross,
#jesy road pe aik car dusary car ko cross kerti h or agy nikal jati h isy dodge kehty h.
#ager dodge=False ho ga to car dusari car ke uper se guzry ge
# Out:
# <AxesSubplot:xlabel='tip', ylabel='day'>

# %%
#how to manage individual color in hue color
import seaborn as sns
#set theme/ canvas board of whitegrid color/background color
sns.set_style(style='whitegrid')
#load datset
tip=sns.load_dataset('tips')
#palette ={"Yes": "green", "No": "blue"}
#using indexing 
sns.boxplot(x="tip",y="day",data=tip,hue='smoker',palette={"Yes": "green", "No": "blue"},dodge=True)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='day'>

# %%
import seaborn as sns

# %%
import seaborn as sns
import pandas as pd
#set style theme
sns.set_style(style='whitegrid')
data = pd.read_csv('data.csv')
data
#load dataset
#kashti=sns.load_dataset('data')
#kashti
# Out:
#      Gender  Location    Age Qualification_completed    field_of_study  \
# 0      Male  Pakistan  36-40                 Masters  Natural Sciences
# 1      Male  Pakistan  26-30               Bachelors             CS/IT
# 2      Male  Pakistan  31-35                 Masters       Enginnering
# 3    Female  Pakistan  31-35                 Masters             CS/IT
# 4    Female  Pakistan  26-30                 Masters       Enginnering
# ..      ...       ...    ...                     ...               ...
# 370    Male  Pakistan  26-30                 Masters       Enginnering
# 371    Male  Pakistan  31-35               Bachelors       Enginnering
# 372    Male  Pakistan  21-25               Bachelors             CS/IT
# 373    Male  Pakistan  26-30                 Masters       Enginnering
# 374  Female  Pakistan  31-35                 Masters       Mathematics
#
#            Purpose_for_chilla What are you? Blood group   \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
#set style theme
sns.set_style(style='whitegrid')
# data = pd.read_csv('data.csv')
session=sns.load_dataset('data')
sns.boxplot(x='Gender',y='Age',data=session)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ConnectionAbortedError                    Traceback (most recent call last)
# <ipython-input-1-3340e2f60113> in <module>
#       5 sns.set_style(style='whitegrid')
#       6 # data = pd.read_csv('data.csv')
# ----> 7 session=sns.load_dataset('data')
#       8 sns.boxplot(x='Gender',y='Age',data=session)
#       9 plt.show()
#
# ~\anaconda3\lib\site-packages\seaborn\utils.py in load_dataset(name, cache, data_home, **kws)
#     483                                   os.path.basename(full_path))
#     484         if not os.path.exists(cache_path):
# --> 485             if name not in get_dataset_names():
#     486                 raise ValueError(f"'{name}' is not one of the example datasets.")
#     487             urlretrieve(full_path, cache_path)
#
# ~\anaconda3\lib\site-packages\seaborn\utils.py in get_dataset_names()
#     418     url = "https://github.com/mwaskom/seaborn-data"
# ...

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
kashti= sns.load_dataset('titanic')
sns.boxplot(x='survived',y='age',data=kashti)
# Out:
# <AxesSubplot:xlabel='survived', ylabel='age'>

# %%
sns.boxplot(x='survived',y='age',showmeans=True,data=kashti)
# Out:
# <AxesSubplot:xlabel='survived', ylabel='age'>

# %%
sns.boxplot(x='survived',y='age',data=kashti,showmeans=True,
            meanprops={"marker":"+","markersize":"15","markeredgecolor":"red"})
plt.xlabel("How many survived",size=14,weight="bold"),
plt.ylabel("Age(years)",size=12,weight="bold"),
plt.title("Box plot of kitne dooby or kitne bah gye",size=14,weight="bold")
plt.show()

# %%
sns.boxplot(x='survived',y='age',data=kashti)
